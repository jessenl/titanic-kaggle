# %% [markdown]
# <a href="https://colab.research.google.com/github/jessenl/titanic-kaggle/blob/main/titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing data

# %%
from google.colab import files
uploaded = files.upload()
# !unzip titanic.zip
# Out:
#      <input type="file" id="files-1a3a0410-bc4d-4137-992b-5159810c6172" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1a3a0410-bc4d-4137-992b-5159810c6172">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving titanic.zip to titanic.zip

# %%
import pandas as pd
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %% [markdown]
# Cleaning and transforming

# %%
def transformar_sexo(value):
    if value == 'female':
        return 1
    else:
        return 0

cols= ['Sex_binario', 'Age', 'Pclass', 'SibSp', 'Parch', 'Fare']
train['Sex_binario'] = train['Sex'].map(transformar_sexo)
test['Sex_binario'] = test['Sex'].map(transformar_sexo)

X = train[cols].fillna(-1)
y = train['Survived']

# %% [markdown]
# Create, train and validate a model

# %%
from sklearn.model_selection import train_test_split
import numpy as np

# %%
np.random.seed(0)
X_train, X_valid, y_train, y_valid = train_test_split(X, y, test_size=0.5)

# %%
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=0, verbose=0,
#                        warm_start=False)

# %%
p = model.predict(X_valid)

# %%
# acurracy
np.mean(y_valid == p)
# Out:
# 0.7802690582959642

# %% [markdown]
# Validação cruzada

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RepeatedKFold

# %% [markdown]
# Error Analisys

# %%
kf = RepeatedKFold(n_splits=2, n_repeats=10, random_state=10)
results = []
for rows_train, rows_valid in kf.split(X):
    print('Treino: ', rows_train.shape[0])
    print('Teste: ', rows_valid.shape[0])

    X_train, X_valid = X.iloc[rows_train], X.iloc[rows_valid]
    y_train, y_valid = y.iloc[rows_train], y.iloc[rows_valid]

    model = RandomForestClassifier(n_estimators=100, n_jobs=-1, random_state=0)
    model.fit(X_train, y_train)
    p = model.predict(X_valid)
    acc = np.mean(y_valid == p)
    results.append(acc)
    print('Acc: ', acc)
    print()
# Out:
# Treino:  445
# Teste:  446
# Acc:  0.7869955156950673
#
# Treino:  446
# Teste:  445
# Acc:  0.7797752808988764
#
# Treino:  445
# Teste:  446
# Acc:  0.827354260089686
#
# Treino:  446
# Teste:  445
# Acc:  0.8179775280898877
#
# Treino:  445
# Teste:  446
# Acc:  0.7847533632286996
#
# Treino:  446
# Teste:  445
# Acc:  0.7842696629213484
#
# Treino:  445
# Teste:  446
# Acc:  0.8161434977578476
#
# Treino:  446
# Teste:  445
# Acc:  0.7842696629213484
#
# Treino:  445
# Teste:  446
# Acc:  0.8004484304932735
#
# Treino:  446
# Teste:  445
# Acc:  0.8
#
# Treino:  445
# Teste:  446
# Acc:  0.8183856502242153
#
# Treino:  446
# Teste:  445
# Acc:  0.802247191011236
#
# Treino:  445
# Teste:  446
# Acc:  0.8116591928251121
#
# Treino:  446
# Teste:  445
# Acc:  0.8067415730337079
#
# Treino:  445
# Teste:  446
# Acc:  0.820627802690583
#
# Treino:  446
# Teste:  445
# Acc:  0.7887640449438202
#
# Treino:  445
# Teste:  446
# Acc:  0.8385650224215246
#
# Treino:  446
# Teste:  445
# ...

# %%
X_valid_check = train.iloc[rows_valid].copy()
X_valid_check['p'] = p
X_valid_check.head()
# Out:
#    PassengerId  Survived  Pclass  ... Embarked Sex_binario  p
# 0            1         0       3  ...        S           0  0
# 1            2         1       1  ...        C           1  1
# 2            3         1       3  ...        S           1  0
# 3            4         1       1  ...        S           1  1
# 4            5         0       3  ...        S           0  0
#
# [5 rows x 14 columns]

# %%
erros = X_valid_check[X_valid_check['Survived'] != X_valid_check['p']]
erros = erros[['PassengerId', 'Pclass', 'Name',	'Sex',	'Age',	'SibSp', 
               'Parch','Ticket','Fare', 'Cabin', 'Embarked', 'Sex_binario', 
               'p', 'Survived']]
erros.head()
# Out:
#     PassengerId  Pclass  ...  p Survived
# 2             3       3  ...  0        1
# 21           22       2  ...  0        1
# 22           23       3  ...  0        1
# 23           24       1  ...  0        1
# 25           26       3  ...  0        1
#
# [5 rows x 14 columns]

# %%
mulheres = erros[erros['Sex'] == 'female']
homens = erros[erros['Sex'] == 'male']

# %%
mulheres.sort_values('Survived')
# Out:
#      PassengerId  Pclass  ...  p Survived
# 888          889       3  ...  1        0
# 501          502       3  ...  1        0
# 498          499       1  ...  1        0
# 882          883       3  ...  1        0
# 474          475       3  ...  1        0
# 419          420       3  ...  1        0
# 357          358       2  ...  1        0
# 254          255       3  ...  1        0
# 503          504       3  ...  1        0
# 654          655       3  ...  1        0
# 772          773       2  ...  1        0
# 177          178       1  ...  1        0
# 852          853       3  ...  1        0
# 854          855       2  ...  1        0
# 593          594       3  ...  1        0
# 830          831       3  ...  0        1
# 855          856       3  ...  0        1
# 866          867       2  ...  0        1
# 677          678       3  ...  0        1
# 2              3       3  ...  0        1
# 216          217       3  ...  0        1
# ...

# %%
homens.sort_values('Survived')
# Out:
#      PassengerId  Pclass  ...  p Survived
# 238          239       2  ...  1        0
# 442          443       3  ...  1        0
# 422          423       3  ...  1        0
# 373          374       1  ...  1        0
# 371          372       3  ...  1        0
# 698          699       1  ...  1        0
# 262          263       1  ...  1        0
# 231          232       3  ...  1        0
# 214          215       3  ...  1        0
# 721          722       3  ...  1        0
# 169          170       3  ...  1        0
# 544          545       1  ...  1        0
# 783          784       3  ...  1        0
# 139          140       1  ...  1        0
# 122          123       2  ...  1        0
# 118          119       1  ...  1        0
# 102          103       1  ...  1        0
# 48            49       3  ...  1        0
# 27            28       1  ...  1        0
# 34            35       1  ...  1        0
# 579          580       3  ...  0        1
# ...

# %% [markdown]
# Mais variáveis

# %%
train['Embarked_S'] = (train['Embarked'] == 'S').astype(int)
train['Embarked_C'] = (train['Embarked'] == 'C').astype(int)

train['Cabine_nula'] = train['Cabin'].isnull().astype(int)

train['Nome_contem_Miss'] = train['Name'].str.contains('Miss').astype(int)
train['Nome_contem_Mrs'] = train['Name'].str.contains('Mrs').astype(int)

train['Nome_contem_Master'] = train['Name'].str.contains('Master').astype(int)
train['Nome_contem_Col'] = train['Name'].str.contains('Col').astype(int)
train['Nome_contem_Major'] = train['Name'].str.contains('Major').astype(int)
train['Nome_contem_Mr'] = train['Name'].str.contains('Mr').astype(int)

# %%
cols= ['Sex_binario', 'Age', 'Pclass', 'SibSp', 'Parch', 
       'Fare', 'Embarked_S', 'Embarked_C', 'Cabine_nula',
       'Nome_contem_Miss', 'Nome_contem_Mrs', 'Nome_contem_Master',
       'Nome_contem_Col', 'Nome_contem_Major', 'Nome_contem_Mr']
X = train[cols].fillna(-1)
y = train['Survived'].fillna(-1)

# %%
from sklearn.linear_model import LogisticRegression

# %%
results2 = []
for rows_train, rows_valid in kf.split(X):
    print('Treino: ', rows_train.shape[0])
    print('Teste: ', rows_valid.shape[0])

    X_train, X_valid = X.iloc[rows_train], X.iloc[rows_valid]
    y_train, y_valid = y.iloc[rows_train], y.iloc[rows_valid]

    model = LogisticRegression()
    model.fit(X_train, y_train)
    p = model.predict(X_valid)
    acc = np.mean(y_valid == p)
    results2.append(acc)
    print('Acc: ', acc)
    print()
# Out:
# Treino:  445
# Teste:  446
# Acc:  0.8318385650224215
#
# Treino:  446
# Teste:  445
# Acc:  0.8067415730337079
#
# Treino:  445
# Teste:  446
# Acc:  0.8139013452914798
#
# Treino:  446
# Teste:  445
# Acc:  0.802247191011236
#
# Treino:  445
# Teste:  446
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# ...

# %%
# %matplotlib inline
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['test']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
pylab.hist(results2), pylab.hist(results, alpha=0.8)
# Out:
# ((array([1., 2., 3., 1., 7., 0., 2., 1., 1., 2.]),
#   array([0.79775281, 0.80205825, 0.80636368, 0.81066912, 0.81497456,
#          0.81927999, 0.82358543, 0.82789087, 0.8321963 , 0.83650174,
#          0.84080717]),
#   <a list of 10 Patch objects>),
#  (array([4., 2., 0., 4., 2., 2., 4., 0., 1., 1.]),
#   array([0.77977528, 0.78565426, 0.79153323, 0.7974122 , 0.80329118,
#          0.80917015, 0.81504913, 0.8209281 , 0.82680707, 0.83268605,
#          0.83856502]),
#   <a list of 10 Patch objects>))

# %%
np.mean(results)
# Out:
# 0.8041457147175896

# %%
test['Embarked_S'] = (test['Embarked'] == 'S').astype(int)
test['Embarked_C'] = (test['Embarked'] == 'C').astype(int)

test['Cabine_nula'] = test['Cabin'].isnull().astype(int)

test['Nome_contem_Miss'] = test['Name'].str.contains('Miss').astype(int)
test['Nome_contem_Mrs'] = test['Name'].str.contains('Mrs').astype(int)

test['Nome_contem_Master'] = test['Name'].str.contains('Master').astype(int)
test['Nome_contem_Col'] = test['Name'].str.contains('Col').astype(int)
test['Nome_contem_Major'] = test['Name'].str.contains('Major').astype(int)
test['Nome_contem_Mr'] = test['Name'].str.contains('Mr').astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-d5b29efe91a1> in <module>()
# ----> 1 test['Embarked_S'] = (test['Embarked'] == 'S').astype(int)
#       2 test['Embarked_C'] = (test['Embarked'] == 'C').astype(int)
#       3
#       4 test['Cabine_nula'] = test['Cabin'].isnull().astype(int)
#       5
#
# TypeError: 'PytestTester' object is not subscriptable

# %% [markdown]
# Retrain the model

# %%
test = pd.read_csv('test.csv')
test['Sex_binario'] = test['Sex'].map(transformar_sexo)

# %%
model = LogisticRegression()
model.fit(X, y)
p = model.predict(test[cols].fillna(-1))

# %% [markdown]
# Create a file to submit to Kaggle

# %%
sub = pd.Series(p, name='Survived',index=test['PassengerId'])

# %%
sub.to_csv('second_model.csv',  header=True)

# %%
# !head -n10 frist_model.csv
